# %% [markdown]
# # TP2 Arbres de décision

# %% [markdown]
# ## Importation des librairies

# %%
import numpy as np					        # Pour la manipulation de tableaux
import pandas as pd					        # Pour l’importation des données
import matplotlib.pyplot as plt				# Pour l’affichage de l’arbre
import os							        # Pour le répertoire par défaut

# %% [markdown]
# ## Répertoire par défaut (à modifier)

# %%
os.chdir('C:\\INFO\\R4.04 Optimisation')

# %% [markdown]
# ## Importation du fichier exemple.csv

# %%
exemple = pd.read_table('Exemple.csv', sep = ';', decimal = ',', encoding = 'ANSI')
exemple.dtypes

# %%
exemple.head()

# %% [markdown]
# # Préparation des données - Contraintes

# %% [markdown]
# ## Première contrainte : pas de valeur manquante
# S’il y en a, une méthode classique est de les remplacer : on parle d’imputation.
# Cette imputation peut se faire par la moyenne, la médiane, la valeur modale (la plus fréquente)…

# %% [markdown]
# ### Détection des valeurs manquantes
# la méthode **isna()** permet de vérifier l'existence de données manquantes

# %%
exemple.isna().head()

# %% [markdown]
# Plus synthétiquement, nous pouvons sommer sur les colonnes (True --> 1, False --> 0)

# %%
exemple.isna().sum()

# %% [markdown]
# Il y a donc une valeur manquante dans la variable X1 (quantitative) et une dans la variable X2 (qualitative).

# %% [markdown]
# ### Variable X1 quantitative : imputation par la moyenne
# Nous aurions aussi pu utiliser la médiane ou le mode.

# %% [markdown]
# #### Calculs de la moyenne et du mode

# %%
exemple['X1'].mean()

# %%
exemple['X1'].median()

# %% [markdown]
# #### Imputation par la moyenne : fillna()

# %%
exemple['X1']=exemple['X1'].fillna(exemple['X1'].mean())

# %%
exemple.isna().sum()

# %%
exemple.head()

# %% [markdown]
# ### Variable X3 qualitative : imputation par le mode
# Attention, il peut y avoir plusieurs valeurs modales, c'est la raison pour laquelle, la méthode **mode()** renvoie une Serie.
# Dans l'exemple de la variable X3, la série n'a qu'une valeur ('Bien'), il n'y a qu'une valeur modale.

# %%
exemple['X3'].mode()

# %%
type(exemple['X3'].mode())

# %% [markdown]
# #### Imputation par le mode : fillna()

# %%
exemple['X3']=exemple['X3'].fillna(exemple['X3'].mode()[0])

# %%
exemple.isna().sum()

# %%
exemple.head()

# %% [markdown]
# Avant de continuer, copie profonde de exemple dans exemple_num

# %%
exemple_num = exemple.copy(deep = True)

# %% [markdown]
# ## Deuxième contrainte : les données doivent se présenter sous la forme d'un DataFrame de nombres
# Ce qui signifie que les modalités des variables qualitatives doivent être recodées de façon **numérique**

# %% [markdown]
# ### Recodage des modalités de X2 et X3 sous forme numérique

# %% [markdown]
# Pour renommer des modalités, on peut utiliser des dictionnaires de correspondance.
# **Pour la variable X2 :**

# %%
modalitesX2 = exemple["X2"].unique()
modalitesX2

# %%
dicX2 = {}
i=1
for i in range(len(modalitesX2)) : 
    dicX2[modalitesX2[i]] = i

dicX2

# %% [markdown]
# *Recodage avec replace*

# %%
exemple_num['X2'].replace(dicX2, inplace = True)

# %%
exemple_num.head()

# %% [markdown]
# **Pour la variable X3**

# %%
modalitesX3 = exemple_num["X3"].unique()
modalitesX3

# %%
dicX3 = {}
i=1
for mod in modalitesX3 : 
    dicX3[mod] = i
    i = i+1

# %%
exemple_num['X3'].replace(dicX3, inplace = True)

# %%
exemple_num.head()

# %% [markdown]
# ## Création de la cible
# Il n'est pas nécessaire, pour la cible, que ses modalités soient recodées **numériquement**

# %%
cible = exemple['Y']

# %% [markdown]
# ## Variables explicatives
# Sélection des variables qui vont être utilisées comme variables explicatives.
# **explicatives** est un DataFrame contenant les trois variables X1, X2 et X3

# %%
explicatives = exemple_num.iloc[:, 0:3]
explicatives.head()

# %% [markdown]
# # Paramétrage et création de l’arbre
# Avec, au préalable, l'importation des fonctions **DecisionTreeClassifier** et **plot_tree** du module **tree** de **sklearn** :

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %% [markdown]
# ## Paramétrage de l'arbre : DecisionTreeClassifier
# Profondeur maximale de l'arbre : 3
# Taille minimale des feuilles : 5

# %%
class_arbre = DecisionTreeClassifier(max_depth = 3, min_samples_leaf=5)

# %% [markdown]
# ## Calcul de l'arbre

# %%
digit_tree = class_arbre.fit(explicatives, cible)

# %% [markdown]
# ## Visualisation de l'arbre

# %%
plt.figure(figsize = (12,10))
plot_tree(digit_tree, fontsize = 12)
plt.show()

# %% [markdown]
# ## Amélioration
# Deux options :
# * **feature_names** : pour l'utilisation des noms de variables dans l'arbre (au lieu de leur numérotation)
# * **filled = True** : pour le coloriage des nœuds en fonction de la proportion de 1 dans le noeud.

# %%
plt.figure(figsize = (12,10))
plot_tree(digit_tree, fontsize = 12, filled=True, feature_names= list(explicatives.columns))
plt.show()

# %% [markdown]
# # Attention, par cette méthode, les variables qualitatives **nominales** ne sont pas correctement traitées
# En effet, les **modalités** ne peuvent être regroupées que par valeurs consécutives, comme s’il s’agissait de variables qualitatives **ordinales**.
# Une solution est d’associer à chaque variable nominale autant de variables binaires que de modalités.
# Nous utilisons, pour cela, la méthode **get_dummies()**

# %%
ex = pd.get_dummies(exemple, columns = ['X2','X3'])
ex.head()

# %%
explicatives2 = ex.iloc[:,[0,2,3,4,5,6,7]] 
#Calcul de l’arbre dans digit_tree
digit_tree = class_arbre.fit(explicatives2, cible)

#Visualisation de l’arbre
plt.figure(figsize = (12,10))
plot_tree(digit_tree, fontsize = 12, filled=True, feature_names= list(explicatives2.columns))
plt.show()

# %% [markdown]
# # Sujet du TP2

# %% [markdown]
# # Partie I
# Les données portent sur les variétés rouges et blanches du vin portugais « Vinho Verde ».
# *Référence : Cortez,Paulo, Cerdeira,A., Almeida,F., Matos,T., and Reis,J.. (2009). Wine Quality. UCI Machine Learning Repository. https://doi.org/10.24432/C56S3T.*
# Vous commencerez par travailler sur le fichier **winequality-red-alc.csv** concernant les variétés « rouge » du Vinho Verde.
# Les variables que nous avons retenues dans ce fichier (lire avec attention) :
# * **citric acid :** acide citrique – variable quantitative – de  0 à 1,66
# * **residual sugar :** sucre résiduel – variable quantitative – de 0,6 à 65,8
# * **sulphates :** sulfates – variable quantitative – de 0,22 à 1,08
# * **alcohol :** degré d’alcool -  variable qualitative – modalités :  « <10 », « [10,11[ » ,  « [11,12[ », « >12 »
# * **quality :** score d’évaluation de la qualité du vin – variable quantitative – de 3 à 8
# * **avis :** directement lié au score précédent (quality) – variable qualitative – modalités : bon (si quality >6), pas bon (sinon)
# Nous allons construire un **arbre de décision** à partir de ces données
# Les variables explicatives sont les variables **citric acid, residual sugar, sulphates, alcohol.**
# La variable cible est **avis**

# %% [markdown]
# ## Importer les données sous Python et réaliser un arbre de décision, la variable cible étant la variable avis.

# %% [markdown]
# *On pourra vérifier, sous Excel ou avec Python, les calculs effectués sur les premiers noeuds*

# %%
os.chdir('C:\\INFO\\R4.04 Optimisation')
# Importation de la table winequality-red-alc.csv
vinrouge = pd.read_table('winequality-red-alc.csv', sep = ';', decimal = ',',encoding='ANSI')
# pour afficher le type des variables 
vinrouge.dtypes
# Out:
# citric acid       float64
# residual sugar    float64
# pH                float64
# sulphates         float64
# alcohol            object
# quality             int64
# avis               object
# dtype: object

# %%
vinrouge.head()
# Out:
#    citric acid  residual sugar    pH  sulphates alcohol  quality     avis
# 0         0.49             2.1  3.16       0.63     <10        3  pas bon
# 1         0.66             2.2  3.25       0.57     <10        3  pas bon
# 2         0.05             2.1  3.31       0.55     <10        3  pas bon
# 3         0.00             1.2  3.32       0.51     <10        3  pas bon
# 4         0.42             1.5  3.38       0.86     <10        3  pas bon

# %% [markdown]
# # Détection de valeurs manquantes

# %%
vinrouge.isnull().sum()
# Out:
# citric acid       0
# residual sugar    0
# pH                0
# sulphates         0
# alcohol           0
# quality           0
# avis              0
# dtype: int64

# %% [markdown]
# Il n'y a pas de valeurs manquantes

# %% [markdown]
# # Recodage des modalités des modalités des variables qualitatives

# %%
modalites_alc = vinrouge["alcohol"].unique()
modalites_alc
# Out:
# array(['<10', '[10,11[', '[11,12[', '>12'], dtype=object)

# %% [markdown]
# #### Remarque : s'il avait fallu réordonner les modalités de **alcohol** nous aurions pu passer par une variable Categorical :

# %%
vinrouge['alcohol'] = pd.Categorical(vinrouge['alcohol'],
                                     categories = ['<10', '[10,11[', '[11,12[', '>12'], 
                                     ordered = True)
vinrouge['alcohol'].unique()
# Out:
# ['<10', '[10,11[', '[11,12[', '>12']
# Categories (4, object): ['<10' < '[10,11[' < '[11,12[' < '>12']

# %% [markdown]
# ### Création d'un dictionnaire de correspondances entre les modalités et les valeurs numériques

# %%
dic_alc = {}
i=1
for mod in modalites_alc: 
    dic_alc[mod] = i
    i = i+1

# %% [markdown]
# ### Recodage

# %%
vinrouge['alcohol'].replace(dic_alc, inplace = True)
vinrouge.head()
# Out:
#    citric acid  residual sugar    pH  sulphates alcohol  quality     avis
# 0         0.49             2.1  3.16       0.63       1        3  pas bon
# 1         0.66             2.2  3.25       0.57       1        3  pas bon
# 2         0.05             2.1  3.31       0.55       1        3  pas bon
# 3         0.00             1.2  3.32       0.51       1        3  pas bon
# 4         0.42             1.5  3.38       0.86       1        3  pas bon

# %% [markdown]
# # Cible et variables explicatives

# %%
cible = vinrouge['avis']
explicatives = vinrouge.iloc[:,0:6]
explicatives.head()
# Out:
#    citric acid  residual sugar    pH  sulphates alcohol  quality
# 0         0.49             2.1  3.16       0.63       1        3
# 1         0.66             2.2  3.25       0.57       1        3
# 2         0.05             2.1  3.31       0.55       1        3
# 3         0.00             1.2  3.32       0.51       1        3
# 4         0.42             1.5  3.38       0.86       1        3

# %% [markdown]
# # Arbre
# ## Paramétrage de l'arbre

# %%
class_arbre = DecisionTreeClassifier(max_depth = 3, min_samples_leaf=5)
class_arbre.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# ## Calcul et représentation de l'arbre

# %%
digit_tree = class_arbre.fit(explicatives, cible)

#Visualisation de l’arbre
plt.figure(figsize = (12,10))
plot_tree(digit_tree, fontsize = 12, filled=True, feature_names= list(explicatives.columns))
plt.show()

# %% [markdown]
# ## On recommence avec les bonnes variables explicatives
# La variable **quality** étant liée (fonctionnellement) à la variable **avis**, on obtient deux nœuds purs. L'arbre est sans intérêt.
# Il faut donc enlever la variable **quality** des variables explicatives.

# %%
cible = vinrouge['avis']
explicatives = vinrouge.iloc[:,0:5]
explicatives.head()
# Out:
#    citric acid  residual sugar    pH  sulphates alcohol
# 0         0.49             2.1  3.16       0.63       1
# 1         0.66             2.2  3.25       0.57       1
# 2         0.05             2.1  3.31       0.55       1
# 3         0.00             1.2  3.32       0.51       1
# 4         0.42             1.5  3.38       0.86       1

# %%
digit_tree = class_arbre.fit(explicatives, cible)

#Visualisation de l’arbre
plt.figure(figsize = (12,10))
plot_tree(digit_tree, fontsize = 12, filled=True, feature_names= list(explicatives.columns))
plt.show()

# %%
digit_tree = class_arbre.fit(explicatives, cible)

#Visualisation de l’arbre
plt.figure(figsize = (15,10))
plot_tree(digit_tree, fontsize = 12, filled=True, feature_names= list(explicatives.columns))
plt.show()

# %% [markdown]
# # Arbre de régression
# Pour l'arbre de régression, il faut prendre une variable cible quantitative.
# Nous allons prendre la variable **quality**.
# La variable **avis** ne devra pas être prise en variable explicative, elle est directement liée à la variable **quality**.

# %%
cible = vinrouge['quality']
explicatives = vinrouge.iloc[:,0:5]
explicatives.head()
# Out:
#    citric acid  residual sugar    pH  sulphates alcohol
# 0         0.49             2.1  3.16       0.63       1
# 1         0.66             2.2  3.25       0.57       1
# 2         0.05             2.1  3.31       0.55       1
# 3         0.00             1.2  3.32       0.51       1
# 4         0.42             1.5  3.38       0.86       1

# %% [markdown]
# Pour l'arbre de régression, on utilise **DecisionTreeRegressor**

# %%
from sklearn.tree import DecisionTreeRegressor
# Paramétrage préalable de l'arbre
class_arbre = DecisionTreeRegressor(max_depth = 3, min_samples_leaf=2)
# Calcul des informations de l’arbre dans digit_free
digit_tree = class_arbre.fit(explicatives, cible)

#Représentation graphique de l’arbre
plt.figure(figsize = (40,15))  # set plot size (denoted in inches)
plot_tree(digit_tree, 
          fontsize = 22,
          filled=True,
          feature_names=list(explicatives.columns))
plt.show()

# %% [markdown]
# # Echantillons de test et d'apprentissage

# %%
from sklearn.model_selection import train_test_split
explicatives_train, explicatives_test, cible_train, cible_test  = train_test_split(explicatives,
                                                                                   cible,
                                                                                   test_size=0.25,
                                                                                   random_state=4)
explicatives_train.head()

# %% [markdown]
# # Partie II

# %% [markdown]
# Les données portent maintenant sur les employés d’une entreprise : **employes.csv**
#
# ### Liste des variables :
# * **Attrition :** variable cible, indiquant si l’employé a quitté (« oui ») volontairement l’entreprise
# * **Age :** âge de l’employé
# * **Deplacements :** variable qualitative relative aux déplacements professionnels de l’employé
# 0 : Pas de déplacement professionnel
# 1 : Peu de déplacements professionnels
# 2 : Déplacements professionnels fréquents
# * **Departement :** variable qualitative relative au service dans lequel travaille l’employé : Ressources humaines, Recherche & Développement, Service commercial
# * **DistanceDomicile :** variable quantitative, indiquant la distance domicile/travail de l’employé
# * **NiveauFormation :** variable qualitative correspondant au niveau d’étude de l’employé
# 1 : Brevet
# 2 : Bac
# 3 : Licence/Bachelor
# 4 : Master
# 5 : Doctorat
# * **Genre :** variable qualitative relative au genre de l’employé
# 1 : Homme
# 2 : Femme
# * **StatutMarital :** situation de l’employé
# 1 : Célibataire
# 2 : Divorcé
# 3 : Marié
# * **AnnesDsEnt :** nombre d’années dans l’entreprise, de l’employé
# * **AnneesPromo :** nombre d’années depuis la dernière promotion

# %% [markdown]
# ## Importer les données sous Python et réaliser un premier arbre de décision de profondeur 3 en faisant attention à traiter correctement les variables qualitatives nominales.
